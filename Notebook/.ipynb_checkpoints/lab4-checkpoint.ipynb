# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("test.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    str
#  3   Sex          418 non-null    str
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    str
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     str
#  10  Embarked     418 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 36.1 KB

# %%
df.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
df.describe(include="all")
# Out:
#         PassengerId      Pclass              Name   Sex         Age  \
# count    418.000000  418.000000               418   418  332.000000
# unique          NaN         NaN               418     2         NaN
# top             NaN         NaN  Kelly, Mr. James  male         NaN
# freq            NaN         NaN                 1   266         NaN
# mean    1100.500000    2.265550               NaN   NaN   30.272590
# std      120.810458    0.841838               NaN   NaN   14.181209
# min      892.000000    1.000000               NaN   NaN    0.170000
# 25%      996.250000    1.000000               NaN   NaN   21.000000
# 50%     1100.500000    3.000000               NaN   NaN   27.000000
# 75%     1204.750000    3.000000               NaN   NaN   39.000000
# max     1309.000000    3.000000               NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# count   418.000000  418.000000       418  417.000000               91      418
# unique         NaN         NaN       363         NaN               76        3
# top            NaN         NaN  PC 17608         NaN  B57 B59 B63 B66        S
# freq           NaN         NaN         5         NaN                3      270
# mean      0.447368    0.392344       NaN   35.627188              NaN      NaN
# std       0.896760    0.981429       NaN   55.907576              NaN      NaN
# min       0.000000    0.000000       NaN    0.000000              NaN      NaN
# 25%       0.000000    0.000000       NaN    7.895800              NaN      NaN
# 50%       0.000000    0.000000       NaN   14.454200              NaN      NaN
# 75%       1.000000    0.000000       NaN   31.500000              NaN      NaN
# max       8.000000    9.000000       NaN  512.329200              NaN      NaN

# %%
#Limpieza
#Nombres de columnas en minusculas
df.columns = df.columns.str.strip().str.lower()

# %%
df.columns
# Out:
# Index(['passengerid', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# passengerid      0
# pclass           0
# name             0
# sex              0
# age             86
# sibsp            0
# parch            0
# ticket           0
# fare             1
# cabin          327
# embarked         0
# dtype: int64

# %%
df.drop(columns=["cabin"], inplace=True)

# %%
df.columns
# Out:
# Index(['passengerid', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'embarked'],
#       dtype='str')

# %%
df["age"] = df["age"].fillna(df["age"].median())

# %%
df.isnull().sum()
# Out:
# passengerid    0
# pclass         0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           1
# embarked       0
# dtype: int64

# %%
#Rellenamos el Fare con el valor mas repetido (moda)
df["fare"] = df["fare"].fillna(df["fare"].mode()[0])

# %%
df.isnull().sum()
# Out:
# passengerid    0
# pclass         0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# embarked       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Validar dato
df["age"].min()
# Out:
# np.float64(0.17)

# %%
df
# Out:
#      passengerid  pclass                                          name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         sex   age  sibsp  parch              ticket      fare embarked
# 0      male  34.5      0      0              330911    7.8292        Q
# 1    female  47.0      1      0              363272    7.0000        S
# 2      male  62.0      0      0              240276    9.6875        Q
# 3      male  27.0      0      0              315154    8.6625        S
# 4    female  22.0      1      1             3101298   12.2875        S
# ..      ...   ...    ...    ...                 ...       ...      ...
# 413    male  27.0      0      0           A.5. 3236    8.0500        S
# 414  female  39.0      0      0            PC 17758  108.9000        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  27.0      0      0              359309    8.0500        S
# 417    male  27.0      1      1                2668   22.3583        C
#
# [418 rows x 10 columns]

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\pepit\anaconda3\envs\extraccion9Besc\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
#Graficamos el total de pasajeros por clase
plt.figure(figsize=(10,5)) #Tamaño
sns.countplot(df,x="pclass")
plt.title("Total de pasajerosvpor clase")
plt.xlabel("CLase")
plt.show()

# %%
#Graficamos las clases por genero
plt.figure(figsize=(8,4))
sns.countplot(df,x="sex", hue="pclass")
plt.title("Total de Genero por clases")
plt.xlabel("Genero")
plt.ylabel("Total")
plt.show()

# %%
#Mostramos la edad por genero y clase
plt.figure(figsize=(6,4))
sns.violinplot(df,x="sex", y="age", hue="pclass")
plt.title("Rango de edad por genero y clase")
plt.xlabel("Genero")
plt.ylabel("Edad")
plt.show()

# %%
#Conocimiento
#Los pasajeros de primera clase pagaban tarifas mas altas.
df.groupby("pclass")["fare"].mean()
# Out:
# pclass
# 1    94.280297
# 2    22.202104
# 3    12.438074
# Name: fare, dtype: float64

# %%
#La distribucion muestra que habia mas hombres que mujeres
df["sex"].value_counts()
# Out:
# sex
# male      266
# female    152
# Name: count, dtype: int64
